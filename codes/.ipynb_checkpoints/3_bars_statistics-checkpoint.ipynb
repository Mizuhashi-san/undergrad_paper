# %%
#あらかじめターミナル等で以下のソフトウェアをインストールしておく．
# !pip install ripser
# !pip install persim

#モジュールのインポート
import bars_statistics
import os

#パスの移動
os.chdir('../data')
path = os.getcwd()
print(f"current path : {path}")

# %%
#印欧語族に含まれる30言語
lang_list = ['hy','lt','be','ru','uk','bg','hr','sr','sl','cs','sk','pl','cy','no','da','sv','en','de','nl','el','bn','hi','ur','ro','it','fr','ca','es','gl','pt']
lang_list = ['en','de']

for col in ['birth']:
    for sta in ['mean']:
        plot_point(1, lang_list, col, sta, x=['cosine',1], y=['euclidian',1], annotate=True)
